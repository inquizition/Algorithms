# %%
import numpy as np
import matplotlib.pyplot as plt

fs      =   44100;
length  =   2;
f       =   1000;
t       =   np.linspace(0,length,fs*length)*0.001;

signal = np.sin(2*np.pi*f*t);

plt.plot(t, signal);
plt.show();
